# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os,json

# %%
df0 = pd.read_csv('/Users/nathandhawale/Documents/CodingDojo/Coding/Data-Enrichment/superhero_powers.csv')
df1 = pd.read_csv('/Users/nathandhawale/Documents/CodingDojo/Coding/Data-Enrichment/superhero_info.csv')
df0.info()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   hero_names  667 non-null    object
#  1   Powers      667 non-null    object
# dtypes: object(2)
# memory usage: 10.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hero|Publisher  463 non-null    object
#  1   Gender          463 non-null    object
#  2   Race            463 non-null    object
#  3   Alignment       463 non-null    object
#  4   Hair color      463 non-null    object
#  5   Eye color       463 non-null    object
#  6   Skin color      463 non-null    object
#  7   Measurements    463 non-null    object
# dtypes: object(8)
# memory usage: 29.1+ KB

# %%
df0.duplicated().sum()
# Out:
# 0

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df0.isna().sum()
# Out:
# hero_names    0
# Powers        0
# dtype: int64

# %%
df1.isna().sum()
# Out:
# Hero|Publisher    0
# Gender            0
# Race              0
# Alignment         0
# Hair color        0
# Eye color         0
# Skin color        0
# Measurements      0
# dtype: int64

# %%
df0.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
df1.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
df1['Hero|Publisher'].str.split('|',expand=True)
# Out:
#                    0                  1
# 0             A-Bomb      Marvel Comics
# 1         Abe Sapien  Dark Horse Comics
# 2           Abin Sur          DC Comics
# 3        Abomination      Marvel Comics
# 4      Absorbing Man      Marvel Comics
# ..               ...                ...
# 458     Yellowjacket      Marvel Comics
# 459  Yellowjacket II      Marvel Comics
# 460             Yoda       George Lucas
# 461          Zatanna          DC Comics
# 462             Zoom          DC Comics
#
# [463 rows x 2 columns]

# %%
df1[['Hero','Publisher']] = df1['Hero|Publisher'].str.split('|',expand=True)
df1.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color                                  Measurements  \
# 0    yellow    Unknown  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1      blue       blue   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
#
#          Hero          Publisher
# 0      A-Bomb      Marvel Comics
# 1  Abe Sapien  Dark Horse Comics

# %%
df1 = df1.drop(columns = ['Hero|Publisher'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Powers        463 non-null    object
#  1   Gender        463 non-null    object
#  2   Race          463 non-null    object
#  3   Alignment     463 non-null    object
#  4   Hair color    463 non-null    object
#  5   Eye color     463 non-null    object
#  6   Skin color    463 non-null    object
#  7   Measurements  463 non-null    object
#  8   Hero          463 non-null    object
#  9   Publisher     463 non-null    object
# dtypes: object(10)
# memory usage: 39.8+ KB

# %%
df1['Measurements'].str.split(',',expand=True)
# Out:
#                          0                       1
# 0    {'Height': '203.0 cm'   'Weight': '441.0 kg'}
# 1    {'Height': '191.0 cm'    'Weight': '65.0 kg'}
# 2    {'Height': '185.0 cm'    'Weight': '90.0 kg'}
# 3    {'Height': '203.0 cm'   'Weight': '441.0 kg'}
# 4    {'Height': '193.0 cm'   'Weight': '122.0 kg'}
# ..                     ...                     ...
# 458  {'Height': '183.0 cm'    'Weight': '83.0 kg'}
# 459  {'Height': '165.0 cm'    'Weight': '52.0 kg'}
# 460   {'Height': '66.0 cm'    'Weight': '17.0 kg'}
# 461  {'Height': '170.0 cm'    'Weight': '57.0 kg'}
# 462  {'Height': '185.0 cm'    'Weight': '81.0 kg'}
#
# [463 rows x 2 columns]

# %%
test = df1.loc[0,'Measurements']
test
# Out:
# "{'Height': '203.0 cm', 'Weight': '441.0 kg'}"

# %%
test = test.replace("'", '"')
json.loads(test)
# Out:
# {'Height': '203.0 cm', 'Weight': '441.0 kg'}

# %%
meas = df1['Measurements'].apply(lambda cell: pd.Series(json.loads(cell.replace("'", '"'))))
meas
# Out:
#        Height    Weight
# 0    203.0 cm  441.0 kg
# 1    191.0 cm   65.0 kg
# 2    185.0 cm   90.0 kg
# 3    203.0 cm  441.0 kg
# 4    193.0 cm  122.0 kg
# ..        ...       ...
# 458  183.0 cm   83.0 kg
# 459  165.0 cm   52.0 kg
# 460   66.0 cm   17.0 kg
# 461  170.0 cm   57.0 kg
# 462  185.0 cm   81.0 kg
#
# [463 rows x 2 columns]

# %%
df1 = pd.concat([df1, meas], axis = 1)
df1.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher    Height    Weight
# 0      Marvel Comics  203.0 cm  441.0 kg
# 1  Dark Horse Comics  191.0 cm   65.0 kg
# ...

# %%
df1 = df1.drop(columns = ['Measurements'])
df1.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher    Height    Weight
# 0         A-Bomb      Marvel Comics  203.0 cm  441.0 kg
# 1     Abe Sapien  Dark Horse Comics  191.0 cm   65.0 kg
# 2       Abin Sur          DC Comics  185.0 cm   90.0 kg
# 3    Abomination      Marvel Comics  203.0 cm  441.0 kg
# 4  Absorbing Man      Marvel Comics  193.0 cm  122.0 kg

# %%
df1=df1.replace({'Height':'[a-z]'},'',regex=True)
df1['Height']=df1['Height'].apply(lambda row: float(row))
df1=df1.replace({'Weight':'[a-z]'},'',regex=True)
df1['Weight']=df1['Weight'].apply(lambda row: float(row))
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      463 non-null    object
#  1   Race        463 non-null    object
#  2   Alignment   463 non-null    object
#  3   Hair color  463 non-null    object
#  4   Eye color   463 non-null    object
#  5   Skin color  463 non-null    object
#  6   Hero        463 non-null    object
#  7   Publisher   463 non-null    object
#  8   Height      463 non-null    float64
#  9   Weight      463 non-null    float64
# dtypes: float64(2), object(8)
# memory usage: 36.3+ KB

# %%
df0.loc[2,'Powers']
# Out:
# 'Agility,Accelerated Healing,Cold Resistance,Durability,Underwater breathing,Marksmanship,Weapons Master,Longevity,Intelligence,Super Strength,Telepathy,Stamina,Immortality,Reflexes,Enhanced Sight,Sub-Mariner'

# %%
df0['NewPowers'] = df0['Powers'].str.split(',')

# %%
df0.loc[2,'NewPowers']
# Out:
# ['Agility',
#  'Accelerated Healing',
#  'Cold Resistance',
#  'Durability',
#  'Underwater breathing',
#  'Marksmanship',
#  'Weapons Master',
#  'Longevity',
#  'Intelligence',
#  'Super Strength',
#  'Telepathy',
#  'Stamina',
#  'Immortality',
#  'Reflexes',
#  'Enhanced Sight',
#  'Sub-Mariner']

# %%
exploded = df0.explode('NewPowers')
exploded[['NewPowers']].head()
# Out:
#              NewPowers
# 0              Agility
# 0       Super Strength
# 0              Stamina
# 0          Super Speed
# 1  Accelerated Healing

# %%
powerslist = exploded['NewPowers'].unique()
powerslist
sorted(powerslist)
# Out:
# ['Accelerated Healing',
#  'Adaptation',
#  'Agility',
#  'Animal Attributes',
#  'Animal Control',
#  'Animal Oriented Powers',
#  'Animation',
#  'Anti-Gravity',
#  'Astral Projection',
#  'Astral Travel',
#  'Audio Control',
#  'Banish',
#  'Biokinesis',
#  'Camouflage',
#  'Changing Armor',
#  'Clairvoyance',
#  'Cloaking',
#  'Cold Resistance',
#  'Cryokinesis',
#  'Danger Sense',
#  'Darkforce Manipulation',
#  'Death Touch',
#  'Density Control',
#  'Dexterity',
#  'Dimensional Awareness',
#  'Dimensional Travel',
#  'Duplication',
#  'Durability',
#  'Echolocation',
#  'Elasticity',
#  'Electrical Transport',
#  'Electrokinesis',
#  'Element Control',
#  'Elemental Transmogrification',
#  'Empathy',
#  'Energy Absorption',
#  'Energy Armor',
#  'Energy Beams',
#  'Energy Blasts',
#  'Energy Constructs',
#  'Energy Manipulation',
#  'Energy Resistance',
#  'Enhanced Hearing',
#  'Enhanced Memory',
#  'Enhanced Senses',
#  'Enhanced Sight',
#  'Enhanced Smell',
# ...

# %%
cpower = powerslist[0]
df0[cpower] = df0['Powers'].str.contains(cpower)
df0
# Out:
#           hero_names                                             Powers  \
# 0            3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1             A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2         Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3           Abin Sur                                 Lantern Power Ring
# 4        Abomination  Accelerated Healing,Intelligence,Super Strengt...
# ..               ...                                                ...
# 662  Yellowjacket II                 Flight,Energy Blasts,Size Changing
# 663             Ymir  Cold Resistance,Durability,Longevity,Super Str...
# 664             Yoda  Agility,Stealth,Danger Sense,Marksmanship,Weap...
# 665          Zatanna  Cryokinesis,Telepathy,Magic,Fire Control,Proba...
# 666             Zoom  Super Speed,Intangibility,Time Travel,Time Man...
#
#                                              NewPowers  Agility
# ...

# %%
for cpower in powerslist:
    df0[cpower] = df0['Powers'].str.contains(cpower)
# Out:
# /Users/nathandhawale/opt/anaconda3/envs/dojo-env/lib/python3.7/site-packages/ipykernel_launcher.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`

# %%
df0
# Out:
#           hero_names                                             Powers  \
# 0            3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1             A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2         Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3           Abin Sur                                 Lantern Power Ring
# 4        Abomination  Accelerated Healing,Intelligence,Super Strengt...
# ..               ...                                                ...
# 662  Yellowjacket II                 Flight,Energy Blasts,Size Changing
# 663             Ymir  Cold Resistance,Durability,Longevity,Super Str...
# 664             Yoda  Agility,Stealth,Danger Sense,Marksmanship,Weap...
# 665          Zatanna  Cryokinesis,Telepathy,Magic,Fire Control,Proba...
# 666             Zoom  Super Speed,Intangibility,Time Travel,Time Man...
#
#                                              NewPowers  Agility  \
# ...

# %%
df0 = df0.drop(columns = ['Powers', 'NewPowers'])
df0
# Out:
#           hero_names  Agility  Super Strength  Stamina  Super Speed  \
# 0            3-D Man     True            True     True         True
# 1             A-Bomb    False            True     True        False
# 2         Abe Sapien     True            True     True        False
# 3           Abin Sur    False           False    False        False
# 4        Abomination    False            True     True         True
# ..               ...      ...             ...      ...          ...
# 662  Yellowjacket II    False           False    False        False
# 663             Ymir    False            True    False        False
# 664             Yoda     True           False     True         True
# 665          Zatanna    False           False    False        False
# 666             Zoom    False           False    False         True
#
#      Accelerated Healing  Durability  Longevity  Camouflage  Self-Sustenance  \
# ...

# %%
df1
# Out:
#      Gender               Race Alignment        Hair color Eye color  \
# 0      Male              Human      good           No Hair    yellow
# 1      Male      Icthyo Sapien      good           No Hair      blue
# 2      Male            Ungaran      good           No Hair      blue
# 3      Male  Human / Radiation       bad           No Hair     green
# 4      Male              Human       bad           No Hair      blue
# ..      ...                ...       ...               ...       ...
# 458    Male              Human      good             Blond      blue
# 459  Female              Human      good  Strawberry Blond      blue
# 460    Male     Yoda's species      good             White     brown
# 461  Female              Human      good             Black      blue
# 462    Male            Unknown       bad             Brown       red
#
#     Skin color             Hero          Publisher  Height  Weight
# 0      Unknown           A-Bomb      Marvel Comics   203.0   441.0
# ...

# %%
final = pd.merge(df1, df0, left_on = 'Hero', right_on = 'hero_names')

# %%
final.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher  Height  Weight  ... Weather Control  \
# 0         A-Bomb      Marvel Comics   203.0   441.0  ...           False
# 1     Abe Sapien  Dark Horse Comics   191.0    65.0  ...           False
# 2       Abin Sur          DC Comics   185.0    90.0  ...           False
# 3    Abomination      Marvel Comics   203.0   441.0  ...           False
# 4  Absorbing Man      Marvel Comics   193.0   122.0  ...           False
#
#    Omnipresent  Omniscient  Hair Manipulation  Nova Force  Odin Force  \
# ...

# %%
sns.barplot(data = final, x = 'Super Speed', y = 'Weight')

# %%
sns.barplot(data = final, x = 'Publisher', y = 'Height')
plt.tick_params(labelrotation = 90)
